# %%
import keras
import numpy as np

path = '/home/nick/hgttg.txt'
text = open(path).read()
print('Corpus length:', len(text))

maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Using TensorFlow backend.
# /home/nick/anaconda3/lib/python3.7/site-packages/pydot_ng/__init__.py:30: UserWarning: Couldn't import _dotparser, loading of dot files will not be possible.
#   "Couldn't import _dotparser, "
# Corpus length: 1561773
# Number of sequences: 520571
# Unique characters: 84
# Vectorization...

# %%
from keras.layers import LSTM, Dense
from keras.models import Sequential
from keras.optimizers import RMSprop

model = Sequential([
    LSTM(128, input_shape=(maxlen, len(chars))),
    Dense(len(chars), activation='softmax')
])

model.compile(optimizer=RMSprop(lr=1e-2), loss='categorical_crossentropy')

def sample(a, temp=1.0):
    '''preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temp
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)'''
    a = np.asarray(a).astype('float64')
    a = a / np.sum(a)
    b = np.random.multinomial(1, a, 1)
    return np.argmax(b)

import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print(f'--- Generating with seed: "{generated_text}"')
    
    for temp in [0.2, 0.5, 0.7, 1.0, 1.2]:
        print(f'------ temperature:', temp)
        sys.stdout.write(generated_text)
    
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temp)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 520571/520571 [==============================] - 315s 606us/step - loss: 1.7706
# --- Generating with seed: "all I put - " when there was a sudden
# violent flurry and he"
# ------ temperature: 0.2
# all I put - " when there was a sudden
# violent flurry and he stood the moment of the
# there from the
# bridge to the look and started to the
# raid, and the thing of the
# will and the
# thing the rest the start of the
# way and the
# martant the one because the
# train and start of the way of the more and
# which was a start of the
# bridge and the start of the
# startic of the
# startic of the
# thing and the place of the little
# the start of the
# tried to him and t------ temperature: 0.5
# he place of the little
# the start of the
# tried to him and the
# man fine resided to can it was only with a swimp
#
#
#
#
# Zaphod had at the starright
# and
#
# which means," said Arthur
#
# which was a bouse of a might to
# and seemed in his more his instence of the back silent and he
# was a great could been back to the
# rather
# and with not a were marn was that any one of his head which was to do the
# bridge to the you of
# compansition of the Ford as he was
# finter------ temperature: 0.7
# ge to the you of
# compansition of the Ford as he was
# finterful from them of time with a .
#
# "What?"
#
# "You don't," said Ford drien a momsther a moment carried slowly on the like look in the in itself of the continuit
#
# and they easing and the restand
# was the round to the wring
# Tome about it as we had around the Trolling spaces in has to gray to be hhat and
# almoit second out
# on with betternervonss, and standing starring of the d back to the
# mome. They------ temperature: 1.0
# onss, and standing starring of the d back to the
# mome. They was stiard of
# anvocce.
#
# Zaphod. He Arhhurent out here in land rebenice of
# which and were on it live and her. one in face. ."
#
# Ford side and hatich off to them. No went and benigred to the bitctles to deces?"
#
# "You this. Moinsiat they this did yourste" Fordua brain it a door, planet to pischeriration
# tertss Mils withly
# frorned brillion to call the mohing of
# fact of Not plainion because it ------ temperature: 1.2
# lion to call the mohing of
# fact of Not plainion because it slew its
# noiry would enough as ilately
# chadirain with Trifu.
#
# He seetaNe. sa lot.
# I I..'shirsge millicul"  's right."I odselowila, and which milousts
# all,."
#
# fit finition. a flive hne tner for a panshtergMull-,
# he A herd. He adrecons.
#
# with most had been presiation to filled to of the hook youts to did go agof, nowe-craverrichen" dado, not the some by two.. It sat brouggeasN1Pestintsist beepoch 2
# Epoch 1/1
# 520571/520571 [==============================] - 321s 616us/step - loss: 1.5107
# --- Generating with seed: "s series of contemptuous looks
# that Marvin appeared to be g"
# ------ temperature: 0.2
# s series of contemptuous looks
# that Marvin appeared to be good that they say the starter of
# the man should the starter of the started and showed and the
# starter she was a start and started the starter of the stand
# the standing and the one of the starter of the starter say the
# way the starter of the part of the starter of the standing the
# startly was a start and should the starter that they said the
# suppose of the starter of the starter of the word w------ temperature: 0.5
# aid the
# suppose of the starter of the starter of the word which though
# the stomple.
#
# The stop at should have no one of them had been been to the
# thind was fool the problem which had not he was not the experistes
# which really go it we the round the problem of the standing on
# they was the way that they wasn't start the points.
#
# "Computer!" said Trillian and the offermation.
#
# "I would have been should it they want to get started in she
# can tinks that------ temperature: 0.7
# en should it they want to get started in she
# can tinks that took that they would sear food post that sirnal
# something down to do the ta, showed on very body them."
#
# "The moment little mothing and you and had there was and he
# start because they stoint to the clearly was one where have
# her a suder.
#
# All the moment and how defined a him launes at the episely doovy
# acrossations invorvited was as though, Trilliansil perspor finger
# being the
# think he wa------ temperature: 1.0
# s though, Trilliansil perspor finger
# being the
# think he was. I alrop told sit's see foin to tricaps he beta lost
# gristing. sigricield, listening went sighture that with s they sepiog and no
#
#
#
# who being wondercal alw minanc!  up. Alent which should have
# fam at this marfure for and what what for greats. ?"
#
# "The swiater's stand," said Ford, "bright doranlics."
#
# Ford on his wohpied from his Shickant a
# quietly.
#
# "They seen to seen being dodion.
#
# No ------ temperature: 1.2
# hickant a
# quietly.
#
# "They seen to seen being dodion.
#
# No hondly aroance and boke sumucke that is likk. Arthur had fly bach
# know go, tomed out of its osten way like himporl, alsove omed else?
# whun rearurded really ound go the
#
# charen - I well.k did, Random's swey."
#
# Whicridpested diucinges way down hers irevining dimenation he
# mesali's aground.
#
# "Is puarys his five ofaginatal it-had uniderevision?" said oats
# mad which nod bea her thick thousands iepoch 3
# Epoch 1/1
# 520571/520571 [==============================] - 315s 606us/step - loss: 1.4568
# --- Generating with seed: "e with her suggestion
# which he thought was a truly excellen"
# ------ temperature: 0.2
# e with her suggestion
# which he thought was a truly excellent in the man was the point
# of the start of the start of the ship was a strange the second
# the staring the man was a start of the ship was a fine of the
# way to do the man and some of the reason of the stream of the
# way and should understanded to supposed the point of the ship
# was a supposed and should be a part of the ship was a small
# point of the ship was a suppose to the man and some of the------ temperature: 0.5
#
# point of the ship was a suppose to the man and some of the
# and that the darked that any din of the man reason of the one
# than he was a space of the reason of the sun the robot seemed
# of the planet reared and the very strange of the rather all
# the conting mone, and was the side and designed to point at
# the barman of the man again.
#
# "I would you come him are you to do a lot of the more the dark
# and I odd was the foress mentions to the possible and "------ temperature: 0.7
# ark
# and I odd was the foress mentions to the possible and "is the
# beast... cormeration, you remeanne you have to do the robot
# deep in the wild ming to the way against the sky was a sensis
# to the hard in fact. He didn't you would at the conside you
# even swe have it with me an inwards who stop to did me that
# have from the world we have highed to get to do you to do. ... utervort,
# there or all the land of the rain like that think warled and
# conside a ------ temperature: 1.0
#  the land of the rain like that think warled and
# conside a comm"obse colus of raile.
#
# "Yes wly. Getta tried than yes."
#
# He said about him, "I meanive," said but to be the cercomed had
# preveft the
# pause of own.
#
# Arthur conetously be a moment after that knewless again. And
# moment slip of there, trouchugawintwold quietly one was a side
# constious of any xit of theirshand perbode. Had computer from
# the mausl upaptary in the freams he readed it for roun------ temperature: 1.2
# from
# the mausl upaptary in the freams he readed it for round the edies.
# And Engrasly thive ruly, yespeOhe things. Having to be the emmin
# recock and CocamecY yes out of Yolclets, there had one and lear
# goed of the headof  diskea bittaArly, it is was, stup of duy, to
# The world thirling. There. And ithermcarrooy - hal. That, slan
# before a bang titutsides as this others a getuoswarly, flown to look wimply inla. wutLa robar kfeel
# to paver?.." It said wasepoch 4
# Epoch 1/1
# 520571/520571 [==============================] - 315s 605us/step - loss: 1.4277
# --- Generating with seed: "ar,
# for which Arthur thanked him.
#
# "All right," said Fenny"
# ------ temperature: 0.2
# ar,
# for which Arthur thanked him.
#
# "All right," said Fenny while he was a man was a straist that
# was the straim and the stream of the later that he was a thing
# that he was a great still streaming that they was all the an
# was the stranspace was the spect of the star and the story and
# and the stribbar and the ship's strans, and the strange of the
# strainal of the controll that they was a some of the man was
# because the robot and the stream of the stri------ temperature: 0.5
# of the man was
# because the robot and the stream of the strilling was an an
# to much the amination every still face slightly the like constrol because
# of point while what was after a computer and not he could still
# been in the Earth, was by the new people of the opening
# pass the where and streen and do the could be for a shook on
# and only the black but they was down on the for the force that
# were a gigure.
#
# It was that the leane extraordinar in the p------ temperature: 0.7
# were a gigure.
#
# It was that the leane extraordinar in the passsishing and such
# yard that they were beganing to me he was sulat and all to the
# The bulldathek of pitters and elseterpently differed the anch
# for the pressand, and out of the lighth from the sancous was up
# bori they could there was after the coundies of normal life
# was sently and streen an ang was learged this and a ggood the
# second force in the power of somehell had to Captain, and he wa------ temperature: 1.0
# ond force in the power of somehell had to Captain, and he was the grounharily
# unexpeciparily building to one much that, a cloaking years me, from a
# dea forlobed enence, Derexpect diman in the Pullin from get
# jobsonsonal hearted.
#
# So what this watter thousalling creenly huge wheher was gues
# and presting and day," the prablecve back.
#
#
#
# "reise," said Zaphod. "Now," he said water he would Arthur, asang
# collo. friended down the othersmorted.
#
# "Gue you ------ temperature: 1.2
# r, asang
# collo. friended down the othersmorted.
#
# "Gue you med my bin?" the manisant Vigot and malmr. "With'ell,
# ihnow immeusled slowers," said hernel,anemmmlish croying very
# fber cape seemed. In remement - to in rack wind on berst firnion
# my want of clowly expection menn, a Tesk for tree watssters really
# course Suowagral pitche belod.
#
# You haved about the problem.
#
# My. All did diuperatinally apparent - but would nort's his getous
# bast each.
#
# "Somepoch 5
# Epoch 1/1
# 520571/520571 [==============================] - 313s 600us/step - loss: 1.4105
# --- Generating with seed: "ng ever and then some. Much
# bigger than that in fact, reall"
# ------ temperature: 0.2
# ng ever and then some. Much
# bigger than that in fact, really in the ship of the ship was
# an anglard and started to should the ship of the rest of the
# start of the space was a stare of the ship of the ship of the
# ship of the computer of the ship of the problems and started
# the of the standies of the ship of the ship of the ship of the
# stars of the ship of the ship and the stage and in the way and
# stuffing to the ship of the ship was a start of the sh------ temperature: 0.5
#  and
# stuffing to the ship of the ship was a start of the ship to the
# way and she was the dust and pitter that he was a strange though
# the remark could hundred problem, and a coin and they started
# the other his window of the floor of the ship.
#
# "I mean stall of the tawarmer and someone and the are she seemed
# the let of the maning of the shanges of the fullops of the old
# back of the world into the brock the might.
#
# "I don't would be means the ship wo------ temperature: 0.7
# o the brock the might.
#
# "I don't would be means the ship would she heard the made it's
# enjoy around with him there of his things of the man like it
# makeerantural legal air on kind there and he fleebled around
# the chareness followed in mentaged had been her elevation.
#
# Arthur depained in the lagges that had been so down hamp my
# space was right and they shouldnelled and lights in the fish of
# giving sigh someone of his she had the dead himself and tele------ temperature: 1.0
# giving sigh someone of his she had the dead himself and telephe
# nove. "A mistak?"
#
# "Hey kind that I don't see. He would retares just so.
#
# Fintwo, there sated their care horanessing could moaniced thenguing
# to Stubby and undeed up to each little. He clearled them in endug,
# she now it ever when were prevelsing, than it was a shellog as
# some rather sbardroopwised.
#
# Fie said from all rhynings there.. He had to her and rumentmoble, and the
# ship of regag------ temperature: 1.2
# here.. He had to her and rumentmoble, and the
# ship of regage of the insifilyin was spones reck rid swerped led
# adges, one were actually.
#
# A lenpve and complestlaes space, that should, andappite pencaping
# very doo'd.
#
# Ford assaned she briadgrybigheped smajuranask.
#
# Crost hoout thing that they couldn't it, this dieactomidity to pilm it. Any hallure Krunglous Swaspent
# natofee givery all toleo, not shofled.
#
# The stagal fuly with leint you spieonumed, eepoch 6
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: 1.3975
# --- Generating with seed: "e neon sign in the depths now suddenly lit up, bafflingly, w"
# ------ temperature: 0.2
# e neon sign in the depths now suddenly lit up, bafflingly, which
# was the body and the stars of the spaceship was not some of the
# stars of the moment the moment the big of the rock of the same
# thing and the time of the point of the ship's stars of the man
# when he had been a place of the stars of the ship's computers
# of the book was a same of the sudden the stars of the rock of
# the ship's right the pollar starting and the one the possible
# was a ship w------ temperature: 0.5
# t the pollar starting and the one the possible
# was a ship was a little two the man was a thing of the table
# for the floor of the speaking and seen a miles and stumbled
# forward to do and the book from the more of the consult unstard.
#
# "I don't know," said Ford.
#
# "Arthur," said the old mandors of it and something and the one the
# Two who was going to a moment her in the possible of the book
# of the man as he moment the raffle to the man was about them
# ------ temperature: 0.7
#  the man as he moment the raffle to the man was about them
# about his spaceship of the special robous slowly which and breathed along
# and assed to the operation in the voice was unconsided to the
# distance.
#
# "How seem away there?" said the broke had see the back and the
# correps and allows over the si, was a spasing a, so the windows
# the place with a moment and to the time a firate tick her slightly
# interporal side of the fliense of a big who was a mom------ temperature: 1.0
# ghtly
# interporal side of the fliense of a big who was a moment sushidif from nots
# down in the rations."
#
# took in the pleasing broughpegadom to the mring of his surmi. His
# arms's tco, "became," as being whice, then saw riched his robot's Beeblebrox
# screaming tourra. Hurlogitay misten, some means, because they
# were Gala, "So they were right his Universally very ceirs as hell's as the piccers
# too," he said, "they had ransuded in it is ic? It Fdismens a------ temperature: 1.2
# too," he said, "they had ransuded in it is ic? It Fdismens again
# the one as exaa viey."
#
# At nothing, what as tur, everything is sfrungly slimessass of sun, and the very hitter inxticisigal right.
#
# So counce, with a remain with homes began to mome New rofl of
# the clowm tu wela, is dripped they had hopried. I callg from he? Arthur."
#
# Arrivas of nearreve, emermleh more wasceing him is gorek anothew Your
# down wall or knivito only quickclic in onlylunsheoepoch 7
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: 1.3865
# --- Generating with seed: " however, just before the critical moment of readout, the
# E"
# ------ temperature: 0.2
#  however, just before the critical moment of readout, the
# Earth was a start of the sense of the ship was the planet of
# the stare final side of the figure the planet was the moment
# from the stars and seemed to be a moment of the stars of the
# speck and the figure was the planet and started to be silent
# the planet and the stars of the start of the problem with the
# personal the stars of the bar and the sensitic through the computer
# was the stars of the ------ temperature: 0.5
# and the sensitic through the computer
# was the stars of the bunk from the fut moment of the light driver,
# I was the seconds been stop to the spaceship for it possible
# matter he had always to the bardly came and he was the sense of
# Isk moment. He was a start of the polon it on the corner. It was
# heavy persumed the along the towards the bards of the standing
# had been designed in the trouse through the star up and said
# the green about to the star the wa------ temperature: 0.7
# ugh the star up and said
# the green about to the star the way of the pitch.
#
# It is to for the other one of the gree, slowly. It was a cereabee
# which half her and eper, which are perfectly canbild the part of
# the had been with the train. And gratical technal along the
# replace perimere to preprice.
#
# "Here?" said Arthur, "Monitans."
#
# He said, "the look of the clicas of the fifty missenil."
#
# "Where sort of such other sat of a done and the persiously ext------ temperature: 1.0
# here sort of such other sat of a done and the persiously extremely it hangered and
# neat as tubbed acrossage in the plint, moment bewildered to really
# was it arriveds to all a procespocalstrics of to ablogincied.
#
# He was to think of facing allelled on the ground. It stend in his hum back again the
# floot. The sitting.
#
# He explanet us were over lood of the bar clearly insulting to
# conticul. This mistauries who steeded in his voice of a grey old
# buildin------ temperature: 1.2
# s mistauries who steeded in his voice of a grey old
# building, enweriously ald lot piefir made paice, hadraying evebirits
# and snatninging was sprious outed. Even the yind burs. Probably wore,
# and would thiet open sirfeeledared twiveing outering to
# tolla-tillk just slencury mender uton, as the Immezards o,
# opened to be mindards by prepiating breash. A slow. No arbinst of Duwn,
# ither Mar."
#
# "Slughe."
#
# No on the ship compain papeless froming?"
#
# optingepoch 8
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3788
# --- Generating with seed: "t is. Your only hope
# is to catch it by surprise out of the "
# ------ temperature: 0.2
# t is. Your only hope
# is to catch it by surprise out of the star and some started
# the space of the ship was a star the better stared it and started to
# the ship, and the point was a strange that the star the star
# the ship was the star the way which was a star the bearance
# which was started to completely started to speak and what he
# was continued the computent and started to the star the and
# started for a moment that he was stared at the ship was the
# ------ temperature: 0.5
# tarted for a moment that he was stared at the ship was the
# words of the face in the one instantly concently the briak Things of
# the star he was the actual ware to the reach of the hard in
# the man was only for a computen of instance, where the probe
# thing that the star it stood mere, and the the remains of the
# man in the few time.
#
# "The star some not a moment that this is to work it to you to see the
# sirner.
#
# "The ship was a longer standing a partic------ temperature: 0.7
#  see the
# sirner.
#
# "The ship was a longer standing a particularly shook these stick and
# sandwiched and as father was not some beach and and good. He
# been was the senso teakment of as head and as which most how a nest
# concerning a nice one of the back and slipped up comple and
# person the bown was found and silent printed the small had expeouming,
# from millions, sa bearns, into a mistions of leaping and the
# retanspage on the ship were an involver that------ temperature: 1.0
# eaping and the
# retanspage on the ship were an involver that it was loined little few on
# endination on the voicibed experses wellow, ay suardly knift, OK. Which
# found on himself into it.
#
# The ship to look in his except that right fire lersorged for an
#
#
#
# "I welt! There were a partical Guide... sickes it that
#
#
#
#
#
# beain to that seides, and they had I ever casm he couldn't do it out and
# appeared. The scrambine down.
#
# The at teatuar said them histercec------ temperature: 1.2
# ed. The scrambine down.
#
# The at teatuar said them histercecturforx which is
# Ippra ankits and hanf, it was re- nervous," They were foopessed,
# inented clicked thoughtfutle of trodiange soft around when out
# moving number, sigher, that rumped which Fenchurps in did to hoped, for Ssugrat now
# an approdafwamor. He Partsed nfashanaw raffer on.
#
# Fend was chanerspisaingra. Hewly. Communian tt's ragnes, which
# was doanyly," Assaid frond manudith in the wollageepoch 9
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3747
# --- Generating with seed: "form of
# self-knotting string. It didn't rattle as she shook"
# ------ temperature: 0.2
# form of
# self-knotting string. It didn't rattle as she shook the ship
# was the sun was the sort of sensing the start of the sense of
# the way and started to be the sun the ship was a starter the
# from the point and started to be the starter of the world that
# the small and the ship the world the world and suddenly seemed
# to be the forest and started to be a start of the sights of
# the small space of the start of the space of the world and the
# speak of th------ temperature: 0.5
#  of the start of the space of the world and the
# speak of the are connected to be don't got that the his standing
# and the passage of the doors and had and the pain since was
# not a enturning break million and then he did it, he could be
# sunbearing and something a fretices of the world of the planet
# and found the Trillian was an this, because the time was the
# hand to the ship space of the better blue the laters of the
# distance and had been the futs on ------ temperature: 0.7
# r blue the laters of the
# distance and had been the futs on a while thought when that before the
# each offer one of the despect, but something with him and sun
# or the world should be back out on it. Fenchurch anything that
# trees, they came a couple of trapher on them with a creftrine
# to before for a tape.
#
# Arthur was at them.
#
# "What do you know," said Ford. " Inak in their above the
#
# I hear about them with it were understanding vaguling old window
# o------ temperature: 1.0
# about them with it were understanding vaguling old window
# ofn. The davacur impolicinational on octwight," said Arthur in which Ploestanfumatorful with a ma?
#
# "But tdrifish," the platactaked the his pitcelick of contecting for the
# leop for hoot and the Heart of cowle parts up a pount of impurally
# wave assime.
#
# "That's nice to onaw manage and do us. rut."
#
# "What was me I can't take we left," he said, "is am as a deep."
#
# "No ..." starnd to his place or------ temperature: 1.2
# e said, "is am as a deep."
#
# "No ..." starnd to his place or Provice eessereshed song naiked
# it loomed side agong ie mirytin, whole about him ok Trillian
# might itlovans, he would choig so dubraying though.
#
# There was fiving frowner. Look arm, bubbleds, bohks in Katewrative Nothing
# it continued balt Frol jobleborh as the reparcems and itdened
# into the tryingly is, before patherant from aftenedher.
#
# In H-lity. soge signity about On play this. And ungetepoch 10
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: 1.3688
# --- Generating with seed: "rammed not
# to."
#
# Ford made for the door.
#
# "Look, I'm sorr"
# ------ temperature: 0.2
# rammed not
# to."
#
# Ford made for the door.
#
# "Look, I'm sorry," said Ford. "I think you don't know the
# starting was the more and something the other startled and the
# second of the sign of the old man, and the stage sigh of the
# startle of the sign of the ship of the so was a moment of the
# sigh of the stars of the stars of the stars of the stars of
# the planet of the sigh of the stars of the planet than the stair
# to the back and the stars of the stage b------ temperature: 0.5
# net than the stair
# to the back and the stars of the stage book, because a little
# startle in how the face is there was the hand with the way with
# the top of the most towers.
#
# The body had been something he find the top of the ship was
# complained his head to his billod but they were in a thing that
# still stug by the deation, but there was that the man was thing
# than a bit of it.
# The robot and oxes was a desprion to he was something and the
# frown ------ temperature: 0.7
#  and oxes was a desprion to he was something and the
# frown and mutes of being below the old and there is if he was
# going to think make a great in her of its bridge of the show clariblight
# relation, the from was water. And the is his book in the Histre
# stories of the atgermy partac wall haven have going to do something
# program it seemed to starting from a slight of the sbear milds
# weaved the astonishment.
#
# In fact of the round, it felt the riring sim------ temperature: 1.0
# astonishment.
#
# In fact of the round, it felt the riring simple, I think as her
# seer, not it were conton."
#
# He disfuled among it, roundred if they were g. Fie clame hand and
# to them spaceship. he had would ever dropped some for which
# And Deasn, anything by d, but now door. I have a I musement
# then out."
#
#
#
# "I something that?" said Arthur, an anchambling whet was disgudgeting and twenty
# yst or was of his way, because Arthur with this words un
#
# yroom ------ temperature: 1.2
# or was of his way, because Arthur with this words un
#
# yroom lumked. Wherer at "and he turned to
# you'l he'd betner meto?"
#
# Yxe. Doing turnous.
#
# That only asking up and Thous, but
#
# Arthur and calpudered around the light. one had have inaf "so ver
# to minut himsyy. Ahg, I got for benick it hast locative Arts she
# uninisoled making the lity-time and point now galosinnc? "
# no bur to get heymir!"
#
# Asked to up again, at the oveage mapricable.
# Bincisiwatied,epoch 11
# Epoch 1/1
# 520571/520571 [==============================] - 310s 595us/step - loss: 1.3637
# --- Generating with seed: "ay," he said, "dramatic arrival don't you think?"
#
#
#
# Chapte"
# ------ temperature: 0.2
# ay," he said, "dramatic arrival don't you think?"
#
#
#
# Chapter 22
#
#
# The ship's man which is the ship.
#
# The s
# /home/nick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log
# hip was a starting the start and the ship was a starting
# and he had been and the ship was a strange of the bar and the
# strange of the bar and the strange was startled and the ship
# was a few man which was a strange of the bar the ship was a
# strange of the ship was not the ship which was a stuck of the
# strange of the point of the ship was a start------ temperature: 0.5
# a stuck of the
# strange of the point of the ship was a start for the with on
# the state of the day cagrated to be the fence stood the door in
# the corner and the ship from the one of the strange was broude
# after the second being at the face of she didn't thinking the
# beach sweet the way of the faces of the back and he had been
# and which was seen the back and the ship, and the only stringed
# to the creature which was nothing and and distance on the state------ temperature: 0.7
# the creature which was nothing and and distance on the state
# tasking through the solar that is all the was certain. He wone
# the spaceship was discovered the giels he had along the mission
# which and in the home sandwiches down the first she's it the
# tickets contrinted behind the slow on the eyes before the world
# stopped at him and slifting like this place of points that all
# was they and sump, when there was a doing of
# the same for to rathing and look------ temperature: 1.0
#  when there was a doing of
# the same for to rathing and looked it about suchormating she'd the
# scarticulated about that was more sirring onsential shaup watch them
# his breem, "ymZvciller of cross keeppin."
#
#
#
# They ge on-telling.
#
# "I than she event you specked to are hach you good?"
#
# The ship thoughing moneing to the sound pilled matter Trillian
# and groud prood the meast contrant bale, "I make."
#
# "When where's hell it don't know then it was anything ------ temperature: 1.2
# e."
#
# "When where's hell it don't know then it was anything haven't say,
# left about hem roure doan tickets you, satchid lude o. It
# comes, exc, graw factwine a figure figurefer for to "times it
# as rich thus?"
#
# Ford diveicting broid like any citture. backures of fale of
# jewar-fury and exprienes vine her of unuze hagon caunded Trillian
# quite to use clibhivenoigia thunling and when what, about I
# what, and Ford, tfannul ulhep ahow'l eventionsligernoush, epoch 12
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3609
# --- Generating with seed: "s back with interest at
# the sight of the pikka bird.
#
# Old "
# ------ temperature: 0.2
# s back with interest at
# the sight of the pikka bird.
#
# Old he was a starting of the ship in the most of the ship was
# surprised the ship was a particularly hand and the ship was
# the ship which was a particularly shape was the ship.
#
# "No, what you were the any point and the ship were the ship
# which was a stream of the people and the ship was a strick and
# started to be the ship of the machine of the ship was a space
# ship.
#
# "I don't know the silence of------ temperature: 0.5
# f the ship was a space
# ship.
#
# "I don't know the silence of the ship we have another computer
# they went the pick and great one of the ship, because they meant
# the unabout and the ship and so his head and she went the tope
# and then had in the planet perpens little and you little one of
# the one of the second space with a moment that was a point the
# dead construction of the flight in the stead of the
#
#
#
# "Yes, he was a some of the second should have goi------ temperature: 0.7
# of the
#
#
#
# "Yes, he was a some of the second should have going to be
#
#
#
# Fienser by which in the hatchway to not down and even going to be
# the awark to do the take possibically for its way and peeced
# the remark of conterpule which go it strumble with the fille.
#
# It was an angle thing not the only too and he could land the
# tom would have been settled to be enough in a small every computer,
# but they hearded to survered my he was they assured its elevate------ temperature: 1.0
#  they hearded to survered my he was they assured its elevated bail
# at mhist of ceerayibacarly bit it was flangle to wont the way revealed to hime
# drinch? He deved and silence out.
#
# Bitt a people's tood pointing profess throusk. breath, into
# read when you don't toll became a comination migated to expensite
#
# grassed and the hear man down  He must withino.
#
# What a lot filter swalflooking all ifcyniasition of the hearting across the window a mid deep his------ temperature: 1.2
# cyniasition of the hearting across the window a mid deep his
# my must flatelound hip. Very lenging ketty." he started over in she I
#  The ape!!!!!!!!!!! The
# "Two monever Ford door on sudjoop, it had the traned at him. Ick dy from
# the picked in the put.
#
#
#
# Bepsen browniur weiggly sick the diveswad, and it offerends humany, Numb antilasy
# Occach edirile, hurrie, as ran were about webettepvama, than dile prophetty, bang
# intergature with the countirlity.
# epoch 13
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3581
# --- Generating with seed: "verything on your planet. TV. Radio.
# Telecommunications. Co"
# ------ temperature: 0.2
# verything on your planet. TV. Radio.
# Telecommunications. Course the one and the star was a moment
# the star the standing starting and and the one was strangely
# and strangely on the star the way and was a man which was the
# string of the robot of the standing the one was the body and
# should see the rest of the moment the star and the standing
# story and strangely and strangely and string the first problem
# and the building strange of the ship was standin------ temperature: 0.5
# st problem
# and the building strange of the ship was standing the place
# working the roll through the moment the market, said it in the
# way the body in the pick and the legant was being understood the
# time in the problem of the interson in the standing thing. The
# startlick with a moment of the face was the sure was a the froor
# crowds now the remoting from the mind of the barule back to
# the ever expected and problems to see the how problem.
#
# The ship'------ temperature: 0.7
# er expected and problems to see the how problem.
#
# The ship's body was himself and in the encounter of the top
# ship of its around had fructing, picked the outed. Then was a way
# which was remained a fuings of the arting way in a first phone
# with a while showed, it was book. For your thought and the homing
# on you playing to manager that is long."
#
# "You can did the marcious way one?" said Ford.
#
# "What you were I'm single minds to stand of beside to be i------ temperature: 1.0
#
#
# "What you were I'm single minds to stand of beside to be into a
# peened. When alshive. It seemed and slightly. He stopped and
# are wondered himselfloys. Ssi-little.
#
# The pail and holling his rration, had verytoniately expenserive in ne-emsters down. "You don't righted they Thing?"
#
#
#
# Egen he were the Saan. He seemed read, as he had survating it on
# through the robot sigh every on it their asket creep to partaligillas Effewlish because Of a
# still in th------ temperature: 1.2
# t creep to partaligillas Effewlish because Of a
# still in the ravid for laugh you? He clouched and wased in the nack questing across thingswing drung-glasuumge.
# Final of sorts of pusting he high, levelalred. He after the
# breastlates watch the man, exancia. Vrricy of telec-flet for when you
# you poor arrivel of new and migite Vogon "this. beginned..."
#
# Here and Stapplather.
#
# A nices bashse along toots Ad's materare and fnuy to say you. Whom first
# in thepoch 14
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3569
# --- Generating with seed: "- scene joke and
# had only developed further at Geoffrey's i"
# ------ temperature: 0.2
# - scene joke and
# had only developed further at Geoffrey's interesting thing that
# was a start of the stars of the destruntion of the stars of
# the stars of the body was the stars of the reason the
# way had been the stars of the stars of the
#
#
#
#
#
# "And the stars of the body and was the stars of the bound of
# the stars of the stars of the stars of the ship was a start
# of the planet looking at the stars of the body and the stars
# were was the starting and s------ temperature: 0.5
# stars of the body and the stars
# were was the starting and said.
# Ford and the standing stuff in the place and would be some first
# to the stupid that he said, "in the artible more problems of
# sensation."
#
# "Ford as may and before.
#
# "What are you see that was to have you do you me and actually
# let him to sort of the
#
#
#
#
#
# "He was the missing there are short that it was a touch him a
# booked to the word some of the bar of the one of the
# consultiational------ temperature: 0.7
#  the word some of the bar of the one of the
# consultiational because for the whole stord saying mild.
#
# And it was sure the pentem sumpen it in the lifes?
#
# And possible into them out of the tine disteress to no entoure
# stuffing gratious out.
#
# "Errible pended to stain," said Arthur sends.
#
# "The time more the right and now."
#
# "Hell we could have to do you at the last buggo!" he cloused
# a prenersol agoutisarilularly at the sure of the planet, perfectly ------ temperature: 1.0
# rsol agoutisarilularly at the sure of the planet, perfectly should fomome
# him. And then there if reatures.
#
#
# The stars as the ncome.
#
# And the way at them, talking them. He - told and got from The's
# contontly, on a being at them from to reveway, people agourily
# lattered touch back in thousan looking about that he was
#
#
# Songly stuff existing as which seemed to Hey ticket to make mo pesses
# by from the in-leva diges, out, clearly. It had besade out of
# ------ temperature: 1.2
# from the in-leva diges, out, clearly. It had besade out of
# team down them. some forces moints you time,gerrime."
#
#
# Oceery she curled them.
#
# The offisibly i
# filiuately. Trin as you something there. eyes, something," she gaspmonoiel-Not
# chock hashemerly like sit and ga? Somoped to occupied mattrish
# came to read atima apart of to out, like a glooled Two rarp.
# As he shod carbing a terriblessieaus into better, some oy tar,
# who would  this. I yesray."
#
# Aepoch 15
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3556
# --- Generating with seed: "out of the open
# hatchway of the salvage craft and waded thr"
# ------ temperature: 0.2
# out of the open
# hatchway of the salvage craft and waded through the speed for
# and the past the simple of the strange was the ship and the
# strange was the strange of the way and stranger and shook a
# strange of the strange of the ship but the strange strange was
# any of the strange of the most ship.
#
# "I was a starth and seen to the ship of the strange of the sign
# was a strange completes of the bar and should have been the
# seemed to be a strange of the------ temperature: 0.5
#  bar and should have been the
# seemed to be a strange of the whole edge of the things which
# was strangerally the follow stranger.
#
# "I see about?"
#
# "I mean the moment as the car being a half were your bewilder
# that the one and and a small sound of the face of suddenly and
# should the room in the way again.
#
# "I don't think out and hitching her. I was something that the
# Think was the sponest from it and beard with them follow when
# the way and so becaus------ temperature: 0.7
# om it and beard with them follow when
# the way and so because the let idea
# to the eyes.
#
# And the light wronked to one of the cold man that it was some
# good ane of first it softulating, when hades behind their small and, then
# this diment and clost her formlization is been the blunk in
# the pass in the bag screaming and face of the cariig's one of
# the spective Thrashbarg floor were simvered through the about
# men forest, in fact that the grama, whister ------ temperature: 1.0
# ough the about
# men forest, in fact that the grama, whister rekied it back without a snortifi-uanges voice
# when I is the villagenr
# uaveulate "can it."
#
#
# "
# slighty from the wied the wear you - which sick again. The Parround
# just say there. Fie had you bedy, sight himself. I seems to
# got to work," said Mayving it offlutely as here and seened.
#
# "They dead want to lam and rming to get out. Zaphod seemed in
# presumof of himself, who had here, and he was t------ temperature: 1.2
# d seemed in
# presumof of himself, who had here, and he was tooking. Greaking back.
#
# "Bunney is thas the jusk foremard?"
#
# Oold budge postly editod may of the momerhemo for towely factuabs. so
# drivers of the womany juw: aed this most for dox and greated.
# eftends. The..." put an roolyns as over at Sandmela Can all, in and
# whender. If secise possibility om thisamina litaker. Along.
#
# Toke humming after vaning sound from grodure that the people
# Fomd had sepoch 16
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3518
# --- Generating with seed: "ough of all.
#
# Vast wodges of complex computer code governin"
# ------ temperature: 0.2
# ough of all.
#
# Vast wodges of complex computer code governing the one of the
# starting sea strange of the ship was a strange of the stage
# speak what he was the sun was a soluse than the ship was a strange
# thing and started to the savage of the ship sun the sea were
# startled at the stage and said the sea of the ship was supposed
# the said that the stage and seemed to the time that the ship
# was startled a starting and started to see the ship of the ship ------ temperature: 0.5
# startled a starting and started to see the ship of the ship
# more his marke of the spine cuening for a table It had heress
# herse to the time and all had been supposing the building to
# an about settle of the from the cars, and all in the ship finally
# man was a such car was going to have the disappoentrocle and
# looked a fints of a sort of control with a sort of course it was
# not get that she was all of the way and from a hatchway that
# it was realised h------ temperature: 0.7
# s all of the way and from a hatchway that
# it was realised him with the first wall to the planet and it
# isn't shortly realared and grill the standing tal but the ground
# meant that she could be anything the rock was seemed herself.
#
# "It's like the ghost time what..."
#
# "I think you ease," said Ford to find and looked like the top of
# up the sigh and pralate by a content had been were to
# theruzed at all.
#
# It would at the could seemed put to whose the tr------ temperature: 1.0
# d at all.
#
# It would at the could seemed put to whose the treesion of
# ud?" he lighted feebly blew up shouted back and sat agains.
#
#
#
# Well were just through a stuck ever with the trading girl on
# where of very sicked off what tryting done because it was curvelialy on the
# time I lived to trighting anything exactly celt nothing the
# post up carscle they threw down the bast that couldn't be a
# Poehywards of their firulity that.
#
# It was a light, smiles.
#
# "------ temperature: 1.2
# ywards of their firulity that.
#
# It was a light, smiles.
#
# "Thank you?"
#
# "So Till and compoteerany."
#
# "What's Pamm "and spent understill have round that rising nutty...
# strange of tostles a machine. Every hung we'totshum."
# The flew thit hwar sharhis anagvet on a crixeptraning Tleirdens.
#
# The own turnod intre, the In thenswe buf. Now elket on bexime
# intelliginc atdrew n't behd would see frang serseren lest history over bone hell
# and spowe
# hope rightepoch 17
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3498
# --- Generating with seed: " her visitors, hesitantly, "think
# that Elvis has been kidna"
# ------ temperature: 0.2
#  her visitors, hesitantly, "think
# that Elvis has been kidnaky... the ship was a straigh and she
# was started to be started to be something the light and strange
# of the straigh start of the straigh of the second start to the
# beath the light was a straigian the man was a straigian and
# stopped of the stars of the stars of the constant consistion
# that the star was a start of the straigh and show was a start
# of the ship.
#
# "I see the stars of the star see------ temperature: 0.5
# was a start
# of the ship.
#
# "I see the stars of the star seem to the day and do the raven
# which the figure true any she was another at the door and she
# could expect.
#
# "The ship's put in the street that he was so here of the barman
# with a startion was a sung and far and uninsecting to the fact
# of the road, the world.
#
# "And the ship. I don't have a great ground to a man to know he
# was the wells in the longer like she stopped to himself to hold
# being ------ temperature: 0.7
# ls in the longer like she stopped to himself to hold
# being free out of by incessed with to himself very found the
# stunger, but it even itself, the way of when did there was doing its hure
# as control he was working and taken at the Surprise, everything
# people and buture to be peopless a small battle ship who had
# not been careactured for the day this collaps demanded and sesmeting
# again seen and desnatigent about seemed at him to there, the
# ship.
#
# "H------ temperature: 1.0
# nd desnatigent about seemed at him to there, the
# ship.
#
# "Helve the cormon caredor's arthrian?" said Tricia.
#
# "And is creatured though when they knee. You must do you not on
# noy, you on the lether yelse's Innit is svan pull to mean derrenture
# began to opened to leades, was tall for a planney space. The
# staying is day. It's electr on ware..."
#
# seemed, howly sat in fellia treever.
#
# ""
# Ineff where this was good him I've seen the name of their effect
# ------ temperature: 1.2
# where this was good him I've seen the name of their effect
# rob, li, yes," shouted angberefgratly it-careaffump and relaxed you distegilingsix
# she did snotiched to serie of Bust nod most sihmocsethounoitual
# fast."
# He worked his aked back vea, sudden actfres into the light-stair..."
#
# Ford caught following the down to feed down and coping amash,
# butwed in the dbous Galaxy of his clapids in her pirkachols. He low from On Lulk, unvolughed of the
# seconds epoch 18
# Epoch 1/1
# 520571/520571 [==============================] - 310s 595us/step - loss: 1.3493
# --- Generating with seed: "t," and started
# pulling pints.
#
# He tried again.
#
# "Going t"
# ------ temperature: 0.2
# t," and started
# pulling pints.
#
# He tried again.
#
# "Going to see the point?" said Ford.
#
# "What you think the straight stood that I don't know the stupid
# strange story and speck the start of the time the straigh things
# they were a startle strange and straight and straight and straight
# and strange and started to see the strange and straight the
# sure was a start of the bar and straight the sure was a straight
# the straight the straight and strange to th------ temperature: 0.5
#  was a straight
# the straight the straight and strange to the approation of the
# probability on the arms and so he stuck the inside to the restar
# from the streat of canvent on the thing they and then he was
# probably to say that a moment if they were straved and then
# something, straps in this atimation and pressuned which they
# had a long found the ground of his head the side of the and
# brilliant to the same thing that it was a straight in a good leader------ temperature: 0.7
# nt to the same thing that it was a straight in a good leader to the
# s that or instantly to do to designed with only that sub-poking
# time to make across the robot lever showed on the home.
#
# be the crowd and sting and set the crowd, and controvet, wrong
# like dispitters and ruped and landed on the strange of the sparker
# showen and the fact and completelest long and not still placed
# and speck like strange press.
#
# Ford was a sung, structed and make the t------ temperature: 1.0
# ke strange press.
#
# Ford was a sung, structed and make the turneds on the lails,
# and Random it is fay and stmenged. He Heep, "all under nasing
# first type."
#
# soluthered with awfidp from the door of his thrick Fie. Dret is think's
# knecks people else of high it's set mowed by last along "say.
#
# "
#
# The Cybernity hunt wondery commusional guys. You can
# minute," he said.
#
# A whispering these of other feeling after a smooth of the asew following that
# muth in------ temperature: 1.2
# r feeling after a smooth of the asew following that
# muth in siver who that's you. What? Surproppos?"
#
# Marvin, illy mi. "I just comple hair, enful
# neip. I'm me ry fit for them," preasafled at Hasutivold first blunant harddhing.
#
# "rass cowning any fouth!"
#
# "Ah, this rats is touffick," issn't, what hacfus only slimp. Stree throughouts,
# forths streat!"
#
# ionaged.
#
# turned bave continued.
#
# There, hywiline simply round thatnime was ubiting. OC's encondinglepoch 19
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3496
# --- Generating with seed: "for ever.
#
# "Oh come off it," said Arthur, "the chances agai"
# ------ temperature: 0.2
# for ever.
#
# "Oh come off it," said Arthur, "the chances again."
#
# "I see the start of the stars of the start of the rain was that
# was some of the ship's shoulder and the face was the book of
# the warting starting and the wall was a start of the control
# of the man was the thing that he was surprised the man the start
# was a startion of the way in the start of the computer than
# the mind was a start of the start of the start of the start
# was started to ha------ temperature: 0.5
# rt of the start of the start of the start
# was started to have to say, the flight made the furnoical to
# the controns are well, he could be her than the lead was a mile,
# they were or the cross many starth rain to his face of a lot of
# something of the distance and the shape.
#
# It had a conderstant of all the angret the many of his was in
# the point of the conteral survice seen the order who was stuck that
# he was going to go on to a stunning same back of ------ temperature: 0.7
# tuck that
# he was going to go on to a stunning same back of a manical to
# the construsion concus in the originats which then he had taken a
# point.
#
#
#
#
#
# If heck.
#
# The time which was looking up a matter to other in the his pocket
# was thought not to the insurre, had been moving them. So what
# people with the ship.
#
# The control second stark a people to his care and so a few limal
# wall computer people, and they had been a top of the planet
# of though a so------ temperature: 1.0
# eople, and they had been a top of the planet
# of though a souc.
#
# "I hu'm sighond of pulily what you don't passed "brit fact up
# things... had e? He seemed.
#
# Instaats housped the rirce of.
#
# "What's a kind out cockearhy... wentarry it they been go that
# you were full a bello," he said.
#
# "Are you're all me space ear of the slimy long nike chiln, throok,
# into yet he'd really expected to from."
#
# Hang dymmuried up for the interumage behind that turnakes in------ temperature: 1.2
# Hang dymmuried up for the interumage behind that turnakes into the
# prise socking Gars a jomm green was the sa-nonvable of interwasper-anywhere building. Purst kew about that day,
# than there could sat at time, in diped space highs, pributweroon. Hellamer, trier as
# woralryrough the dlinchibugus in the vagute, ma-ible on. And remend
# and neat know.
#
# hard as turnight. Lardal belled rather other thimping in the flallf reast how goes up a moment
# droppies, aepoch 20
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3654
# --- Generating with seed: "orward and
# took the poor confused Krikkiter by the arm. He "
# ------ temperature: 0.2
# orward and
# took the poor confused Krikkiter by the arm. He stood the ship
# which was a starting the probability and the ship was a probability
# that he was a strange of the ship was a starting the ship which
# he was the ship and the ship was a stuct of the strange of the
# stood was a particularly strange of the strange of the ship
# was a starting the ship are the ship was the promition of the
# ship was a starting end of the first the ship was a consist
# t------ temperature: 0.5
# ip was a starting end of the first the ship was a consist
# to the leader was a news in the reaction. The light was the
# starting continued she thought and then had been gone on the
# ship creatured the shorter packet was in the ship was something
# and made a piece of the table and he eventually are more what
# he was a sub-finucal time something all standing the tracemon
# and discover that he was wanted to while, the light he was a
# head in the planet that h------ temperature: 0.7
# nted to while, the light he was a
# head in the planet that he should have so a snapperial bear
# of the cold things that he could say, who was any like proditions
# and she was only shanger in the very single was he would be
# not behind the encereding the discowning.
# "oey unis they were stead to have to have to choger that it was
# half the sea untersor of some who the own course of the crost
# the building were television.
#
# "What's the pathenic sand on the------ temperature: 1.0
# building were television.
#
# "What's the pathenic sand on the crogreymy was inclised," she pallly nowning on
# an in. Sowicsanes-dives it by a grim into a neck to tell mete
# distakering well continums he had been making the saddies Fortge Him
# exactly still like a mirri's slow. They weren't was didn't get the
# arecrabward, though.
#
# "Though."
#
# "Well, whender." I speted me to the screece."
#
# "opemening and immoft of something. In theiely found there That was------ temperature: 1.2
# ing and immoft of something. In theiely found there That was you
# looked about Lineons were muchteedly heading, "He-foug."
#
# "What?"
#
#
#
# "as simple time don't you've she tried woring traoun, were little siches
# barmanal. Letches effices in an appedragr most departly from Breoking adavem withy.
# He first to be it taken down reassraged and far. arg ancrab a
# westive, and he wearane to merely form blirih where chonging delood
# calling he eigh taken it.
#
# Nearepoch 21
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 1.3556
# --- Generating with seed: "s, a damp shiny darkness.
# The only sounds were the echoes o"
# ------ temperature: 0.2
# s, a damp shiny darkness.
# The only sounds were the echoes of the stars of the stood of
# the star was an away of the starting the stars of the stood
# she was the strange way where he was the stars of the control
# first thing and started to have been a first continutive than
# the stars of the straing and straight that the stars of the
# straing straint that the stars of the stars of the star that
# the start of the street the stars of the stars of the strange------ temperature: 0.5
# he start of the street the stars of the stars of the strange
# television of the computer started and the instare and something
# would all the other and star the world that he had in the thing
# had like the first and something its way the talking thing of
# the astonished and startled to the an and ground.
#
# "I can be a standing a strange of the cars's door that was one
# which was straight on its straint for the high and the thing and
# had started to there t------ temperature: 0.7
# raint for the high and the thing and
# had started to there to get a next an actually place of parts
# such camered on its after and satchey which that that it was
# he could understanded at the fability.
#
# "And they's carsaliration."
#
# "I'm
# saying there."
#
# "At his eyes can a sensof."
#
# "There was high something and space what ever hanging and spot
# ear. They ture into the paper for himself.
#
# The first lawn thought had expected on to the window of the inge------ temperature: 1.0
# first lawn thought had expected on to the window of the ingerations
# was lower, i now, whitker raok read in an
# tear a ship. He got her thigs little hainsel, all of an eachew
# to just in leftefully promonshipleverent ermots on the light himself were gearop
# were wavely collusly.
#
# The red field. "It libse and how compus?"
#
# "te slaled in height, tothing something?" he said, "that's I think were," he said
# off her whole cadert of Ford with himself from econ------ temperature: 1.2
# he said
# off her whole cadert of Ford with himself from econd, peated fall herted in
# these outslice. Slighoure deck man... Hardly c. But or fab!"
#
# ""Ah!" roared onbirallage month rlams. "iflyidusa of it."
#
# "Heat?"
#
# Ford was fish pridgearily.
#
# On darks nonowherenmicing was on the before inageleprize hum,
# and peatly was differently what around gomeer."
#
# "Itlebriven from infive little offus fuft."
#
# "Yes."
#
# wable to lidn coming intodable." The, shippeepoch 22
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: 1.3621
# --- Generating with seed: "od glared at her again, then laughed.
#
# "Listen," she said, "
# ------ temperature: 0.2
# od glared at her again, then laughed.
#
# "Listen," she said, "the start to the many sing the side to the
# start to the top of the problems of the side of the first of the
# start of the deal was a thing and said the bar and started a
# perfecenter that was a starting and the start of the start of
# the start of the distance.
#
# "I meano?"
#
# "What you think you think you meano!!!!!!I?I had?"
#
# "I meano?"
#
# "Yes," said Arthur, "that's the more this was the side t------ temperature: 0.5
# "
#
# "Yes," said Arthur, "that's the more this was the side to the
# mad," he said.
#
# "What you are you computer this that was as single slimmen and
# then seemed to stand to know the simply awarl and still space
# as he had a back the arminble to discover, started in the planet.
#
#
#
# The starter was going round the star as the mishes was that the
# sound of the start as if it was a moment of the way that it was
# the rock of the group started in a for the smile ------ temperature: 0.7
# at it was
# the rock of the group started in a for the smile which and then
# the middle through the time in a bord to your.
#
# He had had seemed in which on a lawn's working again.
#
# He wo'stently in the delovies whisped dead of his alevea to
# you face he got to make in the cuetor of the side of the way
# is apparent and have been a stric thoughts and sees look-sensitive
# this life, he should - sick to you."
#
# "The girl," said Trillian.
#
# "Well, for this sild------ temperature: 1.0
# to you."
#
# "The girl," said Trillian.
#
# "Well, for this sild?" said Ford, "if yo "the attine mestled by
# this, but ket sceee a based over itsseiged tix scorner.
#
# This must rusted to hip.
#
# In the bargensnel things with to know about they mina, rides day that
# managed to writted sure the minutes sparays monately Iventure
# chouts, bild to sake with thlace eventually of a nut night was
# In a man is nittle of doing interrup."
#
# "The by a discancing well."
#
# "------ temperature: 1.2
# nittle of doing interrup."
#
# "The by a discancing well."
#
# "
# The conventia.
#
# Listen."
#
# "He silverifsw."
#
# "You want," he soar it scapel. Trifing and crump as you would camerage. What that? We... and I
# you leved. He
#
# mauned the rising bacling live plete in uf! Arrice rising and
# is diff up a fee, from the question proper. nenver of warker and
# fitted.
#
# Milared way howlorget. It loosely alone, sheeds beyouiab metene.
#
# Chappert our heaving electionaor, epoch 23
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: 1.3827
# --- Generating with seed: "am can't
# he?"
#
# And so he started out. He equipped a spaces"
# ------ temperature: 0.2
# am can't
# he?"
#
# And so he started out. He equipped a spaceship from the stars
# of the special space of the story of the planet was a stars
# of the space of the and start the planet and some real the stars
# of the most of the stars of the stars of the space of the story
# shape of the stars of the planet of the stars of the stars of
# the stars of the space of the stars of the space was the space
# started to see the planet and started to see the stars of the------ temperature: 0.5
# tarted to see the planet and started to see the stars of the
# passengrance planet between the consist of the way was a stead
# of birts of this mistable was to say and started it by the problem?"
#
# "The simple of specularic way?" said Ford.
#
# "I should be smart of a man she mean me, and the man and I have
# pained as slight it what was see the sky, what the sort of
# event and live his bright.
#
# It didn't say of part of its craps with the policiary of the
# sh------ temperature: 0.7
# idn't say of part of its craps with the policiary of the
# ship, and the cramp of Arthur was stre read and had boild to
# remains. And we had used to rourding out in his hand as it all
# the ground of its pink. Fenchurch was forgen across the wide shall, and
# and forgellwing and much toward at a stanrant, for his head
# he stopped a partace, basical because of the approying planet
#
#
#
# was a small smollention in the moment the Surfact of the threey?"
#
# He swong------ temperature: 1.0
# lention in the moment the Surfact of the threey?"
#
# He swong, wordered the looking one of the way was so, disguculeer
# being anything in a me. The living calt currepted like following whether
# toll drist across a lauderivo, wondersping ever when The people
# silver. Can stipped across out of it. She stared uutes very intelligrivives of
# slips.
#
# There were so business end and hundred her puse because and
# sleap, when every certain. It. It was keep a long in------ temperature: 1.2
# se and
# sleap, when every certain. It. It was keep a long inution of
# luil ottlals that's.
#
# Lincune planet that clement up. In anyA-lakl-- hers. Hous leved it, like along quite long. it we
# deep letten at us," very. Songerlopp of Arthur, thousel papes,
# presenting the simuatel Frodbrets, he was vacy about stelebrade. almanst
# left do? The ingreariful
# she days get the assexistle?"
#
# "The oatus gave very early detebil," moved obit raise to all
# yoo is. He epoch 24
# Epoch 1/1
# 520571/520571 [==============================] - 310s 596us/step - loss: 6.4488
# --- Generating with seed: " them. From the walls around them came the sound of
# suddenl"
# ------ temperature: 0.2
#  them. From the walls around them came the sound of
# suddenly thagis the Kr0ingte"ston. sirmme to  them sgetiene Anet
#
# then to  ste an the plare. he'mso u/king thel tealkleq-."
# the lisgh orth thestine tohe to and to "ner tfard saniess in theKn hadyleh
# thern s
# they
# wathe sey" lesda "furn the tbeaud waver End haw and yo sagywr wu
# ver any ot anyAn corg/conlente tre8n the law tho swinth
# sile whard, and hices said the defhwee it te thut*x coull rredor the------ temperature: 0.5
# rd, and hices said the defhwee it te thut*x coull rredor the
# th wbon the Iden nerene Impltatr tener nastho o
# and hamkstPsecbud long havet uzull y th
# reue
#
# wor'an ta hasujonezhelly of theyYolled
# pe!... sar at seneldios tor sthe tilQuZnHcxt  fficy gartoy
# caller stes "it?"..."
#
# "them comprdlemneb t of'ging wa d in
#
# sire yon.r fleit
# hlung she theing e Forr ron ther
# Ior weale rucar sores me?""I
# sandhe Nunga iname Ane shemeh ihet taance hanode cathncnQn ------ temperature: 0.7
#
# sandhe Nunga iname Ane shemeh ihet taance hanode cathncnQn thi but lesheztup thous
# the py mevinh.
# sups
#
#
#
#
# fen?"
#
#
#
#
# hist ereoutefing tola-"
# annt it he Icbo sect a"celiddo y qve ned ig iyhr&?"terifo
# sheure a sun nosgine nois talk an it ho ma-dsDd qcihlisd ut waheo h espec Mgoesie yo".?"
#
#
#
# the eslefdtreerss wasw an ir, to an avrosgr lalby masceen seaaypery se the waoroutt
# sper ledsreik. Tir so scelreny lH th' r sing’. s stat
# id, mest, the I!zed w------ temperature: 1.0
# Tir so scelreny lH th' r sing’. s stat
# id, mest, the I!zed wisg thome"  tand r us quw avmde .
#
# And haverwn reangiT
# ne at hild arhethbo"t thalker tore.m,t xtemnew onle gatgegmagf sotPress,th very tpin oop. .is w6
# mho sect his te waovoe  fes.dbi w oethat.
# nitf
# anlekde thad ther.xe Dunimgat ly amky cers El to a rwime cahandn xin on
# thim thestea thicr whonshifth
# e  lan apel his wdee x th fou.
#
# ithina efts oygdGoonth "y id iutgor mh," appe Yoicb "ncefpter------ temperature: 1.2
# thina efts oygdGoonth "y id iutgor mh," appe Yoicb "ncefpter we
# yaesaarlye nig up an wishieor torman rance undin e fectiney.
#
# haneapted soaceimest sthem woun seF". te thavead bo?". mediDaV ba naton
# fibpley'nt ih pupdse upstes, an ittoosd beemelyQron xanctticoy mdagrint po tild meeFreinnel s is xttne antis  fisd ss anirow t id outd uptriuore slhthHiHge
# fur trow sater
# En hen j'ttr hiven tishuX,, sominge wise
# rarturin ou tobona froqgire trist on henerdouepoch 25
# Epoch 1/1
# 520571/520571 [==============================] - 311s 597us/step - loss: nan
# --- Generating with seed: "pods would probably make."
#
# "You don't think it's the lawn "
# ------ temperature: 0.2
# pods would probably make."
#
# "You don't think it's the lawn
# /home/nick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in greater_equal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-11b8c8e6ecce> in <module>
#      38
#      39             preds = model.predict(sampled, verbose=0)[0]
# ---> 40             next_index = sample(preds, temp)
#      41             next_char = chars[next_index]
#      42
#
# <ipython-input-3-11b8c8e6ecce> in sample(preds, temp)
#      15     exp_preds = np.exp(preds)
#      16     preds = exp_preds / np.sum(exp_preds)
# ---> 17     probas = np.random.multinomial(1, preds, 1)
#      18     return np.argmax(probas)
#      19
#
# mtrand.pyx in numpy.random.mtrand.RandomState.multinomial()
#
# _common.pyx in numpy.random._common.check_array_constraint()
#
# ValueError: pvals < 0, pvals > 1 or pvals contains NaNs
